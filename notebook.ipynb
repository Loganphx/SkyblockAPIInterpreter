# %%
import json
import requests

def get_bazaar_data() -> json:
    x = requests.get('https://api.hypixel.net/skyblock/bazaar?key=41b2a888-f84c-4287-bf56-2012895c8e4d')
    parsed = json.dumps(x.json())
    json_loaded = json.loads(parsed)
    return json_loaded


def get_item_sells(item: str, howMany: int, jsonLoaded: json) -> []:
    stringArray = []
    for k in jsonLoaded:
        if k == item.upper():
            sells = {k: v for k, v in sorted(jsonLoaded[k].items(), reverse=False, key=lambda item: len(item[1]))}
            sells = sells['sell_summary']
    for c, _object in enumerate(sells):
        passing_object = {'amount': _object['amount'],
                          'pricePerUnit': _object['pricePerUnit'],
                          'ordersNum': _object['orders'],
                          'index': c + 1,
                          'item_name': item
                          }
        stringArray.append(passing_object)
    return stringArray


def get_item_buys(item: str, howMany: int, jsonLoaded: json) -> []:
    stringArray = []
    for k in jsonLoaded:
        if k == item.upper():
            buys = {k: v for k, v in sorted(jsonLoaded[k].items(), reverse=False, key=lambda item: len(item[1]))}
            buys = buys['buy_summary']
            # print('BUY ORDERS' + '\n' + str(buys))
    for c, _object in enumerate(buys):
        cnt = len(buys) - c - 1
        _object = buys[cnt]
        passing_object = {'amount': _object['amount'],
                          'pricePerUnit': _object['pricePerUnit'],
                          'ordersNum': _object['orders'],
                          'index': cnt
                          }
        stringArray.append(passing_object)
    return stringArray

# %%
bazaar = get_bazaar_data()
for item in bazaar['products']:
    print(item)
    for info in bazaar['products'][item]:
        if(info != 'product_id'):
            print('\t' + info)
        for orders in bazaar['products'][item][info]:
            if(info != 'product_id'):
                print('\t\t' + str(orders))
            if(info == 'quick_status'):
                for status in bazaar['products'][item][info][orders]:
                    if(info != 'product_id'):
                        if(orders == 'product_id'):
                            print(str(status))
# Out:
# BROWN_MUSHROOM
# 	sell_summary
# 		{'amount': 27431, 'pricePerUnit': 14.1, 'orders': 1}
# 		{'amount': 23183, 'pricePerUnit': 14.0, 'orders': 2}
# 		{'amount': 63526, 'pricePerUnit': 13.9, 'orders': 1}
# 		{'amount': 214905, 'pricePerUnit': 13.6, 'orders': 3}
# 		{'amount': 94977, 'pricePerUnit': 13.4, 'orders': 6}
# 		{'amount': 38753, 'pricePerUnit': 13.2, 'orders': 3}
# 		{'amount': 40960, 'pricePerUnit': 13.1, 'orders': 1}
# 		{'amount': 3380, 'pricePerUnit': 11.7, 'orders': 1}
# 		{'amount': 11479, 'pricePerUnit': 11.5, 'orders': 1}
# 		{'amount': 1024, 'pricePerUnit': 11.2, 'orders': 2}
# 		{'amount': 698, 'pricePerUnit': 10.8, 'orders': 1}
# 		{'amount': 71680, 'pricePerUnit': 10.5, 'orders': 1}
# 		{'amount': 4000, 'pricePerUnit': 4.0, 'orders': 2}
# 		{'amount': 1032, 'pricePerUnit': 1.0, 'orders': 8}
# 	buy_summary
# 		{'amount': 1208, 'pricePerUnit': 14.3, 'orders': 1}
# 		{'amount': 1751, 'pricePerUnit': 14.4, 'orders': 2}
# ...

# %%
def get_sell_summary():
    bazaar = get_bazaar_data()
    for item in bazaar['products']:
        print(item)
        for info in bazaar['products'][item]['sell_summary']:
            print(info)


get_sell_summary()
# Out:
# BROWN_MUSHROOM
# {'amount': 8291, 'pricePerUnit': 14.1, 'orders': 1}
# {'amount': 23183, 'pricePerUnit': 14.0, 'orders': 2}
# {'amount': 63526, 'pricePerUnit': 13.9, 'orders': 1}
# {'amount': 214905, 'pricePerUnit': 13.6, 'orders': 3}
# {'amount': 94977, 'pricePerUnit': 13.4, 'orders': 6}
# {'amount': 38753, 'pricePerUnit': 13.2, 'orders': 3}
# {'amount': 40960, 'pricePerUnit': 13.1, 'orders': 1}
# {'amount': 3380, 'pricePerUnit': 11.7, 'orders': 1}
# {'amount': 11479, 'pricePerUnit': 11.5, 'orders': 1}
# {'amount': 1024, 'pricePerUnit': 11.2, 'orders': 2}
# {'amount': 698, 'pricePerUnit': 10.8, 'orders': 1}
# {'amount': 71680, 'pricePerUnit': 10.5, 'orders': 1}
# {'amount': 4000, 'pricePerUnit': 4.0, 'orders': 2}
# {'amount': 1032, 'pricePerUnit': 1.0, 'orders': 8}
# INK_SACK:3
# {'amount': 861, 'pricePerUnit': 3.2, 'orders': 1}
# {'amount': 37081, 'pricePerUnit': 3.1, 'orders': 3}
# {'amount': 36305, 'pricePerUnit': 3.0, 'orders': 2}
# ...

# %%
def get_buy_summary():
    #bazaar = get_bazaar_data()
    for item in bazaar['products']:
        print(item)
        for info in bazaar['products'][item]['buy_summary']:
            print(info)
get_buy_summary()
# Out:
# BROWN_MUSHROOM
# {'amount': 1208, 'pricePerUnit': 14.3, 'orders': 1}
# {'amount': 1751, 'pricePerUnit': 14.4, 'orders': 2}
# {'amount': 445, 'pricePerUnit': 14.5, 'orders': 1}
# {'amount': 424, 'pricePerUnit': 14.6, 'orders': 1}
# {'amount': 192, 'pricePerUnit': 14.7, 'orders': 1}
# {'amount': 792, 'pricePerUnit': 14.8, 'orders': 1}
# {'amount': 314, 'pricePerUnit': 14.9, 'orders': 1}
# {'amount': 7278, 'pricePerUnit': 15.0, 'orders': 4}
# {'amount': 2240, 'pricePerUnit': 15.1, 'orders': 2}
# {'amount': 2240, 'pricePerUnit': 15.2, 'orders': 1}
# {'amount': 1360, 'pricePerUnit': 15.4, 'orders': 1}
# {'amount': 1428, 'pricePerUnit': 15.5, 'orders': 1}
# {'amount': 267, 'pricePerUnit': 15.7, 'orders': 2}
# {'amount': 1280, 'pricePerUnit': 15.8, 'orders': 3}
# {'amount': 640, 'pricePerUnit': 16.0, 'orders': 3}
# {'amount': 704, 'pricePerUnit': 16.9, 'orders': 2}
# {'amount': 192, 'pricePerUnit': 17.0, 'orders': 1}
# {'amount': 640, 'pricePerUnit': 17.1, 'orders': 2}
# ...

# %%
def get_quick_status():
    for item in bazaar['products']:
        print('\n' + item)
        for status in bazaar['products'][item]['quick_status']:
            print(status + ' , ' + str(bazaar['products'][item]['quick_status'][status]))
get_quick_status()
# Out:
# BROWN_MUSHROOM
# productId , BROWN_MUSHROOM
# sellPrice , 14.054801918427824
# sellVolume , 1972074
# sellMovingWeek , 28452826
# sellOrders , 79
# buyPrice , 14.78445256715403
# buyVolume , 544662
# buyMovingWeek , 6590213
# buyOrders , 282
#
# INK_SACK:3
# productId , INK_SACK:3
# sellPrice , 3.1117761873780094
# sellVolume , 1043912
# sellMovingWeek , 12462579
# sellOrders , 34
# buyPrice , 4.439024946868448
# buyVolume , 2185280
# buyMovingWeek , 8160781
# buyOrders , 379
#
# INK_SACK:4
# productId , INK_SACK:4
# sellPrice , 3.8000976375667133
# sellVolume , 4876810
# sellMovingWeek , 54084644
# sellOrders , 91
# buyPrice , 4.7306492392087165
# buyVolume , 2445039
# buyMovingWeek , 34233510
# buyOrders , 174
#
# TARANTULA_WEB
# productId , TARANTULA_WEB
# sellPrice , 5.0
# sellVolume , 671325
# sellMovingWeek , 16631287
# sellOrders , 25
# buyPrice , 10.93396708286039
# buyVolume , 1525170
# buyMovingWeek , 8149919
# buyOrders , 193
#
# CARROT_ITEM
# productId , CARROT_ITEM
# ...

# %%
# Out:
# 'Mishandle'
